# %% [markdown]
# # Intel Image Classification (CNN - Keras)
#
# Hello, I hope you are having a great day.
#
# In this notebook, I will try the process of implementing CNN with Keras in order to classify images.
# 1. Firstly, we'll import usefull packages.
# 1. Then, we'll load the data, before visualize and preprocess it.
# 1. We'll try a simple CNN model and then we will evaluate its performances.
# 1. We will then use pre trained model to address this challenge aswell.

# %% [markdown]
# # Import Packages

# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\rafra\.conda\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
class_names = ['mountain', 'street', 'glacier', 'buildings', 'sea', 'forest']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %% [markdown]
# # Loading the Data
# We have to write a load_data function that load the images and the labels from the folder.

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['../input/intel/seg_train/seg_train', '../input/intel/seg_test/seg_test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# Loading ../input/intel/seg_train/seg_train
# 100%|██████████████████████████████████████████████████████████████████████████████| 2191/2191 [00:35<00:00, 61.34it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 2271/2271 [00:08<00:00, 277.10it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 2404/2404 [00:02<00:00, 1178.10it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 2512/2512 [00:09<00:00, 252.66it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 2274/2274 [00:16<00:00, 134.25it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 2382/2382 [00:13<00:00, 181.36it/s]
#   0%|▏                                                                                 | 1/437 [00:00<01:12,  6.04it/s]
# Loading ../input/intel/seg_test/seg_test
# 100%|███████████████████████████████████████████████████████████████████████████████| 437/437 [00:04<00:00, 108.91it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 474/474 [00:05<00:00, 93.78it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 553/553 [00:06<00:00, 89.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 525/525 [00:02<00:00, 207.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 510/510 [00:03<00:00, 156.24it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 501/501 [00:02<00:00, 196.23it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %% [markdown]
# # Let's explore the dataset
# We can ask ourselves:
# * How many training and testing examples do we have ?
# * What is the size of the images ?
# * What is the proportion of each observed category ?

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 14034
# Number of testing examples: 3000
# Each image is of size: (150, 150)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %% [markdown]
# ## Good practice: scale the data

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %% [markdown]
# ## Visualize the data
# We can display a random image from the training set.

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %% [markdown]
# We can also display the first 25 images from the training set directly with a loop to get a better view

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %% [markdown]
# # Beginner: Simple Model Creation
#
# Steps are:
# 1. Build the model,
# 1. Compile the model,
# 1. Train / fit the data to the model,
# 1. Evaluate the model on the testing set,
# 1. Carry out an error analysis of our model.
#
# We can build an easy model composed of different layers such as:
# * Conv2D: (32 filters of size 3 by 3) The features will be "extracted" from the image.
# * MaxPooling2D: The images get half sized.
# * Flatten: Transforms the format of the images from a 2d-array to a 1d-array of 150 150 3 pixel values.
# * Relu  : given a value x, returns max(x, 0).
# * Softmax: 6 neurons, probability that the image belongs to one of the classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

# %% [markdown]
# Then, we can compile it with some parameters such as:
# * **Optimizer**: adam = RMSProp + Momentum.
# What is Momentum and RMSProp ?
# * Momentum = takes into account past gradient to have a better update.
# * RMSProp = exponentially weighted average of the squares of past gradients.
# * **Loss function**: we use sparse categorical crossentropy for classification, each images belongs to one class only

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# We fit the model to the data from the training set. The neural network will learn by itself the pattern in order to distinguish each category.

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=20, validation_split = 0.2)
# Out:
# Train on 11227 samples, validate on 2807 samples
# Epoch 1/20
# 11227/11227 [==============================] - 163s 14ms/sample - loss: 1.3756 - accuracy: 0.5208 - val_loss: 1.0725 - val_accuracy: 0.5800
# Epoch 2/20
# 11227/11227 [==============================] - 180s 16ms/sample - loss: 0.8608 - accuracy: 0.6841 - val_loss: 0.8533 - val_accuracy: 0.6826
# Epoch 3/20
# 11227/11227 [==============================] - 178s 16ms/sample - loss: 0.7263 - accuracy: 0.7409 - val_loss: 0.9110 - val_accuracy: 0.6302
# Epoch 4/20
# 11227/11227 [==============================] - 196s 17ms/sample - loss: 0.5882 - accuracy: 0.7943 - val_loss: 0.7201 - val_accuracy: 0.7460
# Epoch 5/20
# 11227/11227 [==============================] - 209s 19ms/sample - loss: 0.4630 - accuracy: 0.8386 - val_loss: 0.7443 - val_accuracy: 0.7446
# Epoch 6/20
# 11227/11227 [==============================] - 191s 17ms/sample - loss: 0.3505 - accuracy: 0.8848 - val_loss: 0.6955 - val_accuracy: 0.7670
# Epoch 7/20
# 11227/11227 [==============================] - 188s 17ms/sample - loss: 0.2621 - accuracy: 0.9157 - val_loss: 0.7272 - val_accuracy: 0.7595
# Epoch 8/20
# 11227/11227 [==============================] - 186s 17ms/sample - loss: 0.1767 - accuracy: 0.9483 - val_loss: 0.7879 - val_accuracy: 0.7492
# Epoch 9/20
# 11227/11227 [==============================] - 186s 17ms/sample - loss: 0.1179 - accuracy: 0.9685 - val_loss: 0.8106 - val_accuracy: 0.7645
# Epoch 10/20
# 11227/11227 [==============================] - 190s 17ms/sample - loss: 0.0740 - accuracy: 0.9837 - val_loss: 0.9089 - val_accuracy: 0.7602
# Epoch 11/20
# 11227/11227 [==============================] - 188s 17ms/sample - loss: 0.0585 - accuracy: 0.9876 - val_loss: 0.9336 - val_accuracy: 0.7763
# Epoch 12/20
# 11227/11227 [==============================] - 181s 16ms/sample - loss: 0.0403 - accuracy: 0.9926 - val_loss: 0.9877 - val_accuracy: 0.7756
# Epoch 13/20
# 11227/11227 [==============================] - 203s 18ms/sample - loss: 0.0358 - accuracy: 0.9939 - val_loss: 1.0429 - val_accuracy: 0.7713
# Epoch 14/20
# 11227/11227 [==============================] - 206s 18ms/sample - loss: 0.0282 - accuracy: 0.9955 - val_loss: 1.0815 - val_accuracy: 0.7706
# Epoch 15/20
# 11227/11227 [==============================] - 217s 19ms/sample - loss: 0.0245 - accuracy: 0.9959 - val_loss: 1.0778 - val_accuracy: 0.7777
# Epoch 16/20
# 11227/11227 [==============================] - 210s 19ms/sample - loss: 0.0155 - accuracy: 0.9983 - val_loss: 1.1534 - val_accuracy: 0.7777
# Epoch 17/20
# 11227/11227 [==============================] - 195s 17ms/sample - loss: 0.0174 - accuracy: 0.9980 - val_loss: 1.1643 - val_accuracy: 0.7777
# Epoch 18/20
# 11227/11227 [==============================] - 196s 17ms/sample - loss: 0.0149 - accuracy: 0.9985 - val_loss: 1.2112 - val_accuracy: 0.7624
# Epoch 19/20
# 11227/11227 [==============================] - 194s 17ms/sample - loss: 0.0159 - accuracy: 0.9980 - val_loss: 1.2129 - val_accuracy: 0.7741
# Epoch 20/20
# 11227/11227 [==============================] - 194s 17ms/sample - loss: 0.0178 - accuracy: 0.9984 - val_loss: 1.2293 - val_accuracy: 0.7713

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(10,5))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "acc")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

# %% [markdown]
# We should evaluate the model performance on test set

# %% [markdown]
# We see that we achieve 0.76 accuracy on the testing test. We got a slight underfitting :(
#
# Let's see how the classifier is doing on random images.

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 3000/3000 [==============================] - 12s 4ms/sample - loss: 1.2632 - accuracy: 0.7660

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)

# %% [markdown]
# ## Error analysis
#
# We can try to understand on which kind of images the classifier has trouble.

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)

# %%
print_mislabeled_images(class_names, test_images, test_labels, pred_labels)

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %% [markdown]
# ## Conclusion: The classifier has trouble with 2 kinds of images.
# It has trouble with street and buildings. Well, it can be understandable as as there are buildings in the street.
# It has also trouble with sea, glacier and moutain as well. It is hard for me to fully distinguish them.
# However, it can detects forest very accurately!

# %% [markdown]
# **Intermediate Update January 2020**
#
# * Feature extraction with VGG16 trained on ImageNet
#
#
# * Ensemble models of Neural Networks with the features extracted from VGG
#
# Inspired from: https://machinelearningmastery.com/model-averaging-ensemble-for-deep-learning-neural-networks/
#
# * Fine Tuning with VGG16 trained on ImageNet

# %% [markdown]
# # Feature extraction with VGG ImageNet

# %% [markdown]
# We can extract features from VGG16.

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input

model = VGG16(weights='imagenet', include_top=False)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Get the features directly from VGG16

# %%
train_features = model.predict(train_images)
test_features = model.predict(test_images)

# %% [markdown]
# ## Visualize the features through PCA

# %%
n_train, x, y, z = train_features.shape
n_test, x, y, z = test_features.shape
numFeatures = x * y * z

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components = 2)

X = train_features.reshape((n_train, x*y*z))
pca.fit(X)

C = pca.transform(X) # Représentation des individus dans les nouveaux axe
C1 = C[:,0]
C2 = C[:,1]

# %%
### Figures

plt.subplots(figsize=(10,10))

for i, class_name in enumerate(class_names):
    plt.scatter(C1[train_labels == i][:1000], C2[train_labels == i][:1000], label = class_name, alpha=0.4)
plt.legend()
plt.title("PCA Projection")
plt.show()

# %% [markdown]
# We can identifying clusters thanks to this PCA. The clusters correspond more or less to the labels.
#
# We see that glacier and mountain points are very close to each other, as VGG sees them as very similar.
#
# We see that there is no distinction between building and street.

# %% [markdown]
# ## Training on top of VGG
#
# Let's train a simple one-layer Neural Network on the features extracted from VGG.

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape = (x, y, z)),
    tf.keras.layers.Dense(50, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

model2.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

history2 = model2.fit(train_features, train_labels, batch_size=128, epochs=15, validation_split = 0.2)
# Out:
# Train on 11227 samples, validate on 2807 samples
# Epoch 1/15
# 11227/11227 [==============================] - 2s 189us/sample - loss: 0.5354 - accuracy: 0.8064 - val_loss: 0.3499 - val_accuracy: 0.8675
# Epoch 2/15
# 11227/11227 [==============================] - 1s 95us/sample - loss: 0.2942 - accuracy: 0.8966 - val_loss: 0.3245 - val_accuracy: 0.8742
# Epoch 3/15
# 11227/11227 [==============================] - 1s 95us/sample - loss: 0.2372 - accuracy: 0.9165 - val_loss: 0.3150 - val_accuracy: 0.8778
# Epoch 4/15
# 11227/11227 [==============================] - 1s 95us/sample - loss: 0.1931 - accuracy: 0.9337 - val_loss: 0.3244 - val_accuracy: 0.8799
# Epoch 5/15
# 11227/11227 [==============================] - 1s 95us/sample - loss: 0.1590 - accuracy: 0.9481 - val_loss: 0.3449 - val_accuracy: 0.8771
# Epoch 6/15
# 11227/11227 [==============================] - 1s 95us/sample - loss: 0.1370 - accuracy: 0.9559 - val_loss: 0.3409 - val_accuracy: 0.8774
# Epoch 7/15
# 11227/11227 [==============================] - 1s 94us/sample - loss: 0.1109 - accuracy: 0.9659 - val_loss: 0.3467 - val_accuracy: 0.8799
# Epoch 8/15
# 11227/11227 [==============================] - 1s 93us/sample - loss: 0.0980 - accuracy: 0.9720 - val_loss: 0.3679 - val_accuracy: 0.8753
# Epoch 9/15
# 11227/11227 [==============================] - 1s 94us/sample - loss: 0.0788 - accuracy: 0.9783 - val_loss: 0.3424 - val_accuracy: 0.8831
# Epoch 10/15
# 11227/11227 [==============================] - 1s 94us/sample - loss: 0.0725 - accuracy: 0.9799 - val_loss: 0.3573 - val_accuracy: 0.8817
# Epoch 11/15
# 11227/11227 [==============================] - 1s 90us/sample - loss: 0.0538 - accuracy: 0.9874 - val_loss: 0.3535 - val_accuracy: 0.8789
# Epoch 12/15
# 11227/11227 [==============================] - 1s 80us/sample - loss: 0.0520 - accuracy: 0.9874 - val_loss: 0.3702 - val_accuracy: 0.8846
# Epoch 13/15
# 11227/11227 [==============================] - 1s 90us/sample - loss: 0.0432 - accuracy: 0.9905 - val_loss: 0.3863 - val_accuracy: 0.8764
# Epoch 14/15
# 11227/11227 [==============================] - 1s 81us/sample - loss: 0.0329 - accuracy: 0.9939 - val_loss: 0.4088 - val_accuracy: 0.8831
# Epoch 15/15
# 11227/11227 [==============================] - 1s 94us/sample - loss: 0.0316 - accuracy: 0.9938 - val_loss: 0.4069 - val_accuracy: 0.8782

# %%
plot_accuracy_loss(history)

# %% [markdown]
# We should get approximately 0.844 accuracy (+0.1 accuracy) over the simple ConvNet.

# %%
test_loss = model2.evaluate(test_features, test_labels)
# Out:
# 3000/3000 [==============================] - 0s 92us/sample - loss: 0.4225 - accuracy: 0.8743

# %% [markdown]
# # Ensemble Neural Networks

# %%
np.random.seed(seed=1997)
# Number of estimators
n_estimators = 10
# Proporition of samples to use to train each training
max_samples = 0.8

max_samples *= n_train
max_samples = int(max_samples)

# %% [markdown]
# We define n_estimators Neural Networks.
#
# Each Neural Network will be trained on random subsets of the training dataset. Each subset contains max_samples samples.

# %%
models = list()
random = np.random.randint(50, 100, size = n_estimators)

for i in range(n_estimators):
    
    # Model
    model = tf.keras.Sequential([ tf.keras.layers.Flatten(input_shape = (x, y, z)),
                                # One layer with random size
                                    tf.keras.layers.Dense(random[i], activation=tf.nn.relu),
                                    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
                                ])
    
    model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
    
    # Store model
    models.append(model)

# %%
histories = []

for i in range(n_estimators):
    # Train each model on a bag of the training data
    train_idx = np.random.choice(len(train_features), size = max_samples)
    histories.append(models[i].fit(train_features[train_idx], train_labels[train_idx], batch_size=128, epochs=10, validation_split = 0.1))
# Out:
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 184us/sample - loss: 0.4995 - accuracy: 0.8140 - val_loss: 0.2845 - val_accuracy: 0.8985
# Epoch 2/10
# 10104/10104 [==============================] - 1s 104us/sample - loss: 0.2409 - accuracy: 0.9161 - val_loss: 0.3013 - val_accuracy: 0.8736
# Epoch 3/10
# 10104/10104 [==============================] - 1s 103us/sample - loss: 0.1728 - accuracy: 0.9449 - val_loss: 0.2069 - val_accuracy: 0.9279
# Epoch 4/10
# 10104/10104 [==============================] - 1s 104us/sample - loss: 0.1389 - accuracy: 0.9549 - val_loss: 0.2210 - val_accuracy: 0.9092
# Epoch 5/10
# 10104/10104 [==============================] - 1s 103us/sample - loss: 0.0979 - accuracy: 0.9722 - val_loss: 0.2518 - val_accuracy: 0.9012
# Epoch 6/10
# 10104/10104 [==============================] - 1s 103us/sample - loss: 0.0862 - accuracy: 0.9761 - val_loss: 0.1714 - val_accuracy: 0.9510
# Epoch 7/10
# 10104/10104 [==============================] - 1s 103us/sample - loss: 0.0663 - accuracy: 0.9827 - val_loss: 0.1670 - val_accuracy: 0.9492
# Epoch 8/10
# 10104/10104 [==============================] - 1s 103us/sample - loss: 0.0526 - accuracy: 0.9891 - val_loss: 0.1647 - val_accuracy: 0.9501
# Epoch 9/10
# 10104/10104 [==============================] - 1s 103us/sample - loss: 0.0382 - accuracy: 0.9936 - val_loss: 0.1686 - val_accuracy: 0.9537
# Epoch 10/10
# 10104/10104 [==============================] - 1s 102us/sample - loss: 0.0344 - accuracy: 0.9942 - val_loss: 0.1846 - val_accuracy: 0.9466
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 189us/sample - loss: 0.5041 - accuracy: 0.8119 - val_loss: 0.3631 - val_accuracy: 0.8807
# Epoch 2/10
# 10104/10104 [==============================] - 1s 114us/sample - loss: 0.2476 - accuracy: 0.9140 - val_loss: 0.2882 - val_accuracy: 0.9047
# Epoch 3/10
# 10104/10104 [==============================] - 1s 114us/sample - loss: 0.1762 - accuracy: 0.9418 - val_loss: 0.2694 - val_accuracy: 0.9127
# Epoch 4/10
# 10104/10104 [==============================] - 1s 114us/sample - loss: 0.1265 - accuracy: 0.9628 - val_loss: 0.2486 - val_accuracy: 0.9172
# Epoch 5/10
# 10104/10104 [==============================] - 1s 114us/sample - loss: 0.0964 - accuracy: 0.9728 - val_loss: 0.2541 - val_accuracy: 0.9270
# Epoch 6/10
# 10104/10104 [==============================] - 1s 113us/sample - loss: 0.0735 - accuracy: 0.9821 - val_loss: 0.2601 - val_accuracy: 0.9207
# Epoch 7/10
# 10104/10104 [==============================] - 1s 113us/sample - loss: 0.0599 - accuracy: 0.9848 - val_loss: 0.2438 - val_accuracy: 0.9288
# Epoch 8/10
# 10104/10104 [==============================] - 1s 113us/sample - loss: 0.0441 - accuracy: 0.9909 - val_loss: 0.2515 - val_accuracy: 0.9270
# Epoch 9/10
# 10104/10104 [==============================] - 1s 113us/sample - loss: 0.0336 - accuracy: 0.9943 - val_loss: 0.2587 - val_accuracy: 0.9314
# Epoch 10/10
# 10104/10104 [==============================] - 1s 114us/sample - loss: 0.0266 - accuracy: 0.9967 - val_loss: 0.2820 - val_accuracy: 0.9323
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 181us/sample - loss: 0.5003 - accuracy: 0.8182 - val_loss: 0.3236 - val_accuracy: 0.8958
# Epoch 2/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.2498 - accuracy: 0.9124 - val_loss: 0.2420 - val_accuracy: 0.9234
# Epoch 3/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.1814 - accuracy: 0.9390 - val_loss: 0.2124 - val_accuracy: 0.9332
# Epoch 4/10
# 10104/10104 [==============================] - 1s 95us/sample - loss: 0.1444 - accuracy: 0.9542 - val_loss: 0.2470 - val_accuracy: 0.9163
# Epoch 5/10
# 10104/10104 [==============================] - 1s 95us/sample - loss: 0.1044 - accuracy: 0.9710 - val_loss: 0.1865 - val_accuracy: 0.9439
# Epoch 6/10
# 10104/10104 [==============================] - 1s 95us/sample - loss: 0.0806 - accuracy: 0.9792 - val_loss: 0.1810 - val_accuracy: 0.9439
# Epoch 7/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.0615 - accuracy: 0.9876 - val_loss: 0.1838 - val_accuracy: 0.9457
# Epoch 8/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.0538 - accuracy: 0.9880 - val_loss: 0.1805 - val_accuracy: 0.9457
# Epoch 9/10
# 10104/10104 [==============================] - 1s 95us/sample - loss: 0.0422 - accuracy: 0.9926 - val_loss: 0.2084 - val_accuracy: 0.9466
# Epoch 10/10
# 10104/10104 [==============================] - 1s 94us/sample - loss: 0.0326 - accuracy: 0.9953 - val_loss: 0.2171 - val_accuracy: 0.9457
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 234us/sample - loss: 0.5149 - accuracy: 0.8126 - val_loss: 0.3506 - val_accuracy: 0.8762
# Epoch 2/10
# 10104/10104 [==============================] - 1s 91us/sample - loss: 0.2602 - accuracy: 0.9095 - val_loss: 0.3393 - val_accuracy: 0.8736
# Epoch 3/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.1824 - accuracy: 0.9384 - val_loss: 0.2879 - val_accuracy: 0.9029
# Epoch 4/10
# 10104/10104 [==============================] - 1s 99us/sample - loss: 0.1343 - accuracy: 0.9607 - val_loss: 0.2858 - val_accuracy: 0.9065
# Epoch 5/10
# 10104/10104 [==============================] - 1s 95us/sample - loss: 0.1090 - accuracy: 0.9674 - val_loss: 0.2687 - val_accuracy: 0.9163
# Epoch 6/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.0838 - accuracy: 0.9777 - val_loss: 0.2718 - val_accuracy: 0.9136
# Epoch 7/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.0664 - accuracy: 0.9839 - val_loss: 0.3104 - val_accuracy: 0.9110
# Epoch 8/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.0569 - accuracy: 0.9868 - val_loss: 0.2794 - val_accuracy: 0.9199
# Epoch 9/10
# 10104/10104 [==============================] - 1s 91us/sample - loss: 0.0435 - accuracy: 0.9903 - val_loss: 0.2639 - val_accuracy: 0.9261
# Epoch 10/10
# 10104/10104 [==============================] - 1s 90us/sample - loss: 0.0347 - accuracy: 0.9938 - val_loss: 0.2668 - val_accuracy: 0.9252
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 178us/sample - loss: 0.5197 - accuracy: 0.8134 - val_loss: 0.3557 - val_accuracy: 0.8896
# Epoch 2/10
# 10104/10104 [==============================] - 1s 97us/sample - loss: 0.2638 - accuracy: 0.9102 - val_loss: 0.2985 - val_accuracy: 0.8985
# Epoch 3/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.1960 - accuracy: 0.9371 - val_loss: 0.2937 - val_accuracy: 0.8967
# Epoch 4/10
# 10104/10104 [==============================] - 1s 97us/sample - loss: 0.1558 - accuracy: 0.9501 - val_loss: 0.2743 - val_accuracy: 0.9127
# Epoch 5/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.1214 - accuracy: 0.9640 - val_loss: 0.2640 - val_accuracy: 0.9252
# Epoch 6/10
# 10104/10104 [==============================] - 1s 97us/sample - loss: 0.1002 - accuracy: 0.9709 - val_loss: 0.2789 - val_accuracy: 0.9172
# Epoch 7/10
# 10104/10104 [==============================] - 1s 99us/sample - loss: 0.0783 - accuracy: 0.9799 - val_loss: 0.2532 - val_accuracy: 0.9270
# Epoch 8/10
# 10104/10104 [==============================] - 1s 98us/sample - loss: 0.0650 - accuracy: 0.9839 - val_loss: 0.2663 - val_accuracy: 0.9270
# Epoch 9/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.0537 - accuracy: 0.9881 - val_loss: 0.2656 - val_accuracy: 0.9297
# Epoch 10/10
# 10104/10104 [==============================] - 1s 95us/sample - loss: 0.0454 - accuracy: 0.9907 - val_loss: 0.2669 - val_accuracy: 0.9297
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 200us/sample - loss: 0.5138 - accuracy: 0.8087 - val_loss: 0.3638 - val_accuracy: 0.8673
# Epoch 2/10
# 10104/10104 [==============================] - 1s 114us/sample - loss: 0.2512 - accuracy: 0.9135 - val_loss: 0.3407 - val_accuracy: 0.8798
# Epoch 3/10
# 10104/10104 [==============================] - 1s 111us/sample - loss: 0.1765 - accuracy: 0.9442 - val_loss: 0.2905 - val_accuracy: 0.8994
# Epoch 4/10
# 10104/10104 [==============================] - 1s 112us/sample - loss: 0.1288 - accuracy: 0.9599 - val_loss: 0.2600 - val_accuracy: 0.9181
# Epoch 5/10
# 10104/10104 [==============================] - 1s 111us/sample - loss: 0.0957 - accuracy: 0.9726 - val_loss: 0.2592 - val_accuracy: 0.9127
# Epoch 6/10
# 10104/10104 [==============================] - 1s 111us/sample - loss: 0.0757 - accuracy: 0.9805 - val_loss: 0.2534 - val_accuracy: 0.9190
# Epoch 7/10
# 10104/10104 [==============================] - 1s 109us/sample - loss: 0.0574 - accuracy: 0.9857 - val_loss: 0.2704 - val_accuracy: 0.9199
# Epoch 8/10
# 10104/10104 [==============================] - 1s 109us/sample - loss: 0.0430 - accuracy: 0.9916 - val_loss: 0.2548 - val_accuracy: 0.9288
# Epoch 9/10
# 10104/10104 [==============================] - 1s 106us/sample - loss: 0.0370 - accuracy: 0.9922 - val_loss: 0.2584 - val_accuracy: 0.9279
# Epoch 10/10
# 10104/10104 [==============================] - 1s 112us/sample - loss: 0.0266 - accuracy: 0.9956 - val_loss: 0.2457 - val_accuracy: 0.9394
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 190us/sample - loss: 0.5493 - accuracy: 0.7964 - val_loss: 0.3374 - val_accuracy: 0.8789
# Epoch 2/10
# 10104/10104 [==============================] - 1s 109us/sample - loss: 0.2630 - accuracy: 0.9051 - val_loss: 0.2552 - val_accuracy: 0.9172
# Epoch 3/10
# 10104/10104 [==============================] - 1s 108us/sample - loss: 0.1888 - accuracy: 0.9403 - val_loss: 0.2283 - val_accuracy: 0.9199
# Epoch 4/10
# 10104/10104 [==============================] - 1s 108us/sample - loss: 0.1482 - accuracy: 0.9541 - val_loss: 0.1950 - val_accuracy: 0.9377
# Epoch 5/10
# 10104/10104 [==============================] - 1s 109us/sample - loss: 0.1078 - accuracy: 0.9699 - val_loss: 0.1789 - val_accuracy: 0.9492
# Epoch 6/10
# 10104/10104 [==============================] - 1s 121us/sample - loss: 0.0825 - accuracy: 0.9805 - val_loss: 0.1923 - val_accuracy: 0.9403
# Epoch 7/10
# 10104/10104 [==============================] - 1s 113us/sample - loss: 0.0685 - accuracy: 0.9834 - val_loss: 0.1779 - val_accuracy: 0.9430
# Epoch 8/10
# 10104/10104 [==============================] - 1s 108us/sample - loss: 0.0559 - accuracy: 0.9876 - val_loss: 0.1917 - val_accuracy: 0.9386
# Epoch 9/10
# 10104/10104 [==============================] - 1s 107us/sample - loss: 0.0430 - accuracy: 0.9920 - val_loss: 0.1679 - val_accuracy: 0.9475
# Epoch 10/10
# 10104/10104 [==============================] - 1s 114us/sample - loss: 0.0305 - accuracy: 0.9954 - val_loss: 0.1722 - val_accuracy: 0.9475
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 223us/sample - loss: 0.4911 - accuracy: 0.8153 - val_loss: 0.3372 - val_accuracy: 0.8753
# Epoch 2/10
# 10104/10104 [==============================] - 1s 122us/sample - loss: 0.2494 - accuracy: 0.9122 - val_loss: 0.2816 - val_accuracy: 0.8994
# Epoch 3/10
# 10104/10104 [==============================] - 1s 111us/sample - loss: 0.1659 - accuracy: 0.9464 - val_loss: 0.2896 - val_accuracy: 0.8931
# Epoch 4/10
# 10104/10104 [==============================] - 1s 111us/sample - loss: 0.1250 - accuracy: 0.9629 - val_loss: 0.2370 - val_accuracy: 0.9279
# Epoch 5/10
# 10104/10104 [==============================] - 1s 110us/sample - loss: 0.0974 - accuracy: 0.9724 - val_loss: 0.2559 - val_accuracy: 0.9127
# Epoch 6/10
# 10104/10104 [==============================] - 1s 111us/sample - loss: 0.0719 - accuracy: 0.9831 - val_loss: 0.2088 - val_accuracy: 0.9377
# Epoch 7/10
# 10104/10104 [==============================] - 1s 111us/sample - loss: 0.0541 - accuracy: 0.9877 - val_loss: 0.2010 - val_accuracy: 0.9457
# Epoch 8/10
# 10104/10104 [==============================] - 1s 111us/sample - loss: 0.0403 - accuracy: 0.9915 - val_loss: 0.2234 - val_accuracy: 0.9261
# Epoch 9/10
# 10104/10104 [==============================] - 1s 111us/sample - loss: 0.0316 - accuracy: 0.9950 - val_loss: 0.2148 - val_accuracy: 0.9359
# Epoch 10/10
# 10104/10104 [==============================] - 1s 110us/sample - loss: 0.0254 - accuracy: 0.9959 - val_loss: 0.2068 - val_accuracy: 0.9430
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 169us/sample - loss: 0.5383 - accuracy: 0.8061 - val_loss: 0.3340 - val_accuracy: 0.8682
# Epoch 2/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.2760 - accuracy: 0.9039 - val_loss: 0.2611 - val_accuracy: 0.9065
# Epoch 3/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.1909 - accuracy: 0.9383 - val_loss: 0.2396 - val_accuracy: 0.9145
# Epoch 4/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.1539 - accuracy: 0.9518 - val_loss: 0.2281 - val_accuracy: 0.9199
# Epoch 5/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.1173 - accuracy: 0.9669 - val_loss: 0.2115 - val_accuracy: 0.9288
# Epoch 6/10
# 10104/10104 [==============================] - 1s 91us/sample - loss: 0.0869 - accuracy: 0.9787 - val_loss: 0.2159 - val_accuracy: 0.9225
# Epoch 7/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.0703 - accuracy: 0.9845 - val_loss: 0.2061 - val_accuracy: 0.9323
# Epoch 8/10
# 10104/10104 [==============================] - 1s 91us/sample - loss: 0.0528 - accuracy: 0.9898 - val_loss: 0.2090 - val_accuracy: 0.9288
# Epoch 9/10
# 10104/10104 [==============================] - 1s 92us/sample - loss: 0.0510 - accuracy: 0.9886 - val_loss: 0.2430 - val_accuracy: 0.9207
# Epoch 10/10
# 10104/10104 [==============================] - 1s 90us/sample - loss: 0.0423 - accuracy: 0.9906 - val_loss: 0.2190 - val_accuracy: 0.9270
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 2s 242us/sample - loss: 0.5042 - accuracy: 0.8124 - val_loss: 0.4077 - val_accuracy: 0.8575
# Epoch 2/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.2632 - accuracy: 0.9037 - val_loss: 0.3730 - val_accuracy: 0.8629
# Epoch 3/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.1783 - accuracy: 0.9422 - val_loss: 0.2845 - val_accuracy: 0.9083
# Epoch 4/10
# 10104/10104 [==============================] - 1s 95us/sample - loss: 0.1290 - accuracy: 0.9622 - val_loss: 0.3173 - val_accuracy: 0.8931
# Epoch 5/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.1061 - accuracy: 0.9686 - val_loss: 0.2754 - val_accuracy: 0.9083
# Epoch 6/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.0777 - accuracy: 0.9807 - val_loss: 0.2766 - val_accuracy: 0.91360.0765 - accuracy: 0.
# Epoch 7/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.0649 - accuracy: 0.9829 - val_loss: 0.2629 - val_accuracy: 0.9181
# Epoch 8/10
# 10104/10104 [==============================] - 1s 95us/sample - loss: 0.0517 - accuracy: 0.9875 - val_loss: 0.2668 - val_accuracy: 0.9207
# Epoch 9/10
# 10104/10104 [==============================] - 1s 96us/sample - loss: 0.0415 - accuracy: 0.9918 - val_loss: 0.2813 - val_accuracy: 0.9199
# Epoch 10/10
# 10104/10104 [==============================] - 1s 95us/sample - loss: 0.0326 - accuracy: 0.9943 - val_loss: 0.2672 - val_accuracy: 0.9243

# %% [markdown]
# We aggregate each model individual predictions to form a final prediction.

# %%
predictions = []
for i in range(n_estimators):
    predictions.append(models[i].predict(test_features))
    
predictions = np.array(predictions)
predictions = predictions.sum(axis = 0)
pred_labels = predictions.argmax(axis=1)

# %% [markdown]
# We should improve our result as we have a lower variance.

# %%
from sklearn.metrics import accuracy_score
print("Accuracy : {}".format(accuracy_score(test_labels, pred_labels)))
# Out:
# Accuracy : 0.8903333333333333

# %% [markdown]
# # Fine Tuning VGG ImageNet

# %%
from keras.models import Model

model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=model.inputs, outputs=model.layers[-5].output)

# %%
train_features = model.predict(train_images)
test_features = model.predict(test_images)

# %%
from keras.layers import Input, Dense, Conv2D, Activation , MaxPooling2D, Flatten

model2 = VGG16(weights='imagenet', include_top=False)

input_shape = model2.layers[-4].get_input_shape_at(0) # get the input shape of desired layer
layer_input = Input(shape = (9, 9, 512)) # a new input tensor to be able to feed the desired layer
# https://stackoverflow.com/questions/52800025/keras-give-input-to-intermediate-layer-and-get-final-output

x = layer_input
for layer in model2.layers[-4::1]:
    x = layer(x)
    
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(100,activation='relu')(x)
x = Dense(6,activation='softmax')(x)

# create the model
new_model = Model(layer_input, x)

# %%
new_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
new_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        multiple                  2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        multiple                  2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        multiple                  2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   multiple                  0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 2, 2, 64)          294976
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               6500
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 606
# =================================================================
# Total params: 7,381,506
# Trainable params: 7,381,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = new_model.fit(train_features, train_labels, batch_size=128, epochs=10, validation_split = 0.2)
# Out:
# Train on 11227 samples, validate on 2807 samples
# Epoch 1/10
# 11227/11227 [==============================] - 402s 36ms/step - loss: 0.7183 - accuracy: 0.7543 - val_loss: 0.3356 - val_accuracy: 0.8853
# Epoch 2/10
# 11227/11227 [==============================] - 454s 40ms/step - loss: 0.3275 - accuracy: 0.8856 - val_loss: 0.2994 - val_accuracy: 0.8942
# Epoch 3/10
# 11227/11227 [==============================] - 437s 39ms/step - loss: 0.2596 - accuracy: 0.9108 - val_loss: 0.2920 - val_accuracy: 0.8970
# Epoch 4/10
# 11227/11227 [==============================] - 443s 39ms/step - loss: 0.2266 - accuracy: 0.9194 - val_loss: 0.2717 - val_accuracy: 0.9002
# Epoch 5/10
# 11227/11227 [==============================] - 411s 37ms/step - loss: 0.1726 - accuracy: 0.9386 - val_loss: 0.2767 - val_accuracy: 0.9099
# Epoch 6/10
# 11227/11227 [==============================] - 401s 36ms/step - loss: 0.1495 - accuracy: 0.9462 - val_loss: 0.3598 - val_accuracy: 0.8899
# Epoch 7/10
# 11227/11227 [==============================] - 409s 36ms/step - loss: 0.1315 - accuracy: 0.9520 - val_loss: 0.3750 - val_accuracy: 0.8835
# Epoch 8/10
# 11227/11227 [==============================] - 424s 38ms/step - loss: 0.1124 - accuracy: 0.9605 - val_loss: 0.3135 - val_accuracy: 0.9035
# Epoch 9/10
# 11227/11227 [==============================] - 412s 37ms/step - loss: 0.0826 - accuracy: 0.9701 - val_loss: 0.3268 - val_accuracy: 0.9109
# Epoch 10/10
# 11227/11227 [==============================] - 381s 34ms/step - loss: 0.0811 - accuracy: 0.9705 - val_loss: 0.3520 - val_accuracy: 0.9092

# %%
plot_accuracy_loss(history)

# %%
from sklearn.metrics import accuracy_score

predictions = new_model.predict(test_features)    
pred_labels = np.argmax(predictions, axis = 1)
print("Accuracy : {}".format(accuracy_score(test_labels, pred_labels)))
# Out:
# Accuracy : 0.9046666666666666
